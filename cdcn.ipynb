# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# Use the kagglehub client library to attach Kaggle resources like competitions, datasets, and models to your session
# Learn more about kagglehub: https://github.com/Kaggle/kagglehub/blob/main/README.md

import kagglehub
# kagglehub.dataset_download('<owner>/<dataset-slug>')
# Out:
# /kaggle/input/datasets/kr1vme/anti-spoof/dataset/fake/2e4709a4-5994-4def-8b6b-a9a81aa6db4b_frame_001_crop.jpg
# /kaggle/input/datasets/kr1vme/anti-spoof/dataset/fake/22_4.avi_75_fake_crop.jpg
# /kaggle/input/datasets/kr1vme/anti-spoof/dataset/fake/8_HR_4.avi_50_fake_crop.jpg
# /kaggle/input/datasets/kr1vme/anti-spoof/dataset/fake/feedingphoto-_05252026.1343193_crop.png
# /kaggle/input/datasets/kr1vme/anti-spoof/dataset/fake/4_HR_2.avi_150_fake_crop.jpg
# /kaggle/input/datasets/kr1vme/anti-spoof/dataset/fake/feedingphoto-_05212026.1504411_crop.png
# /kaggle/input/datasets/kr1vme/anti-spoof/dataset/fake/17_8.avi_25_fake_crop.jpg
# /kaggle/input/datasets/kr1vme/anti-spoof/dataset/fake/16_6.avi_175_fake_crop.jpg
# /kaggle/input/datasets/kr1vme/anti-spoof/dataset/fake/5_2_51_2_1_crop.jpg
# /kaggle/input/datasets/kr1vme/anti-spoof/dataset/fake/6_2_40_2_1_crop.jpg
# /kaggle/input/datasets/kr1vme/anti-spoof/dataset/fake/19_HR_4.avi_25_fake_crop.jpg
# ...

# %%
from pathlib import Path

Path("/kaggle/working/models").mkdir(
    parents=True,
    exist_ok=True
)

# %%
# !git clone https://github.com/Kr1v/Anti-Spoof-Face-Recognition-Model.git
# Out:
# Cloning into 'Anti-Spoof-Face-Recognition-Model'...
# remote: Enumerating objects: 47, done.
# remote: Counting objects: 100% (47/47), done.
# remote: Compressing objects: 100% (36/36), done.
# remote: Total 47 (delta 21), reused 20 (delta 8), pack-reused 0 (from 0)
# Receiving objects: 100% (47/47), 26.19 KiB | 6.55 MiB/s, done.
# Resolving deltas: 100% (21/21), done.

# %%
# %cd /kaggle/working/Anti-Spoof-Face-Recognition-Model
# Out:
# /kaggle/working/Anti-Spoof-Face-Recognition-Model

# %%
# !ls
# Out:
# face_clustering.py  preprocessing_faces.py  README.md  trainer.py

# %%
# %cd /kaggle/working
# !rm -rf Anti-Spoof-Face-Recognition-Model
# !git clone https://github.com/Kr1v/Anti-Spoof-Face-Recognition-Model.git
# Out:
# /kaggle/working
# Cloning into 'Anti-Spoof-Face-Recognition-Model'...
# remote: Enumerating objects: 47, done.
# remote: Counting objects: 100% (47/47), done.
# remote: Compressing objects: 100% (36/36), done.
# remote: Total 47 (delta 21), reused 20 (delta 8), pack-reused 0 (from 0)
# Receiving objects: 100% (47/47), 26.19 KiB | 13.10 MiB/s, done.
# Resolving deltas: 100% (21/21), done.

# %%
# !find /kaggle/input -type d | head -50
# Out:
# /kaggle/input
# /kaggle/input/datasets
# /kaggle/input/datasets/kr1vme
# /kaggle/input/datasets/kr1vme/anti-spoof
# /kaggle/input/datasets/kr1vme/anti-spoof/dataset
# /kaggle/input/datasets/kr1vme/anti-spoof/dataset/fake
# /kaggle/input/datasets/kr1vme/anti-spoof/dataset/real

# %%
import torch

print("CUDA available:", torch.cuda.is_available())
print("Device count:", torch.cuda.device_count())

if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))
# Out:
# CUDA available: True
# Device count: 2
# GPU: Tesla T4

# %%
# !python trainer.py \
    --real_dir "/kaggle/input/datasets/kr1vme/anti-spoof/dataset/real" \
    --fake_dir "/kaggle/input/datasets/kr1vme/anti-spoof/dataset/fake" \
    --epochs 60
# Out:
# python3: can't open file '/kaggle/working/trainer.py': [Errno 2] No such file or directory

# %%
from IPython.display import FileLink
FileLink('/kaggle/working/models/cdcn_best.pt')
# Out:
# /kaggle/working/models/cdcn_best.pt
